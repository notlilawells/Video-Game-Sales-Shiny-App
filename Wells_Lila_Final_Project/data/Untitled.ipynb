# %%
import pandas as pd

# %%
vgsales = pd.read_csv('vgsales.csv')

# %%
vgsales.head(1)
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
vgsales.sort_values('Name', inplace=True)

vgsales.head(100)
vgsales.shape
# Out:
# (16598, 11)

# %%
# Sort the dataset by 'Name' column
df_sorted = vgsales.sort_values(by=['Name'])

# Find the index of the first game that starts with 'A'
idx = df_sorted.loc[df_sorted['Name'].str.startswith('A')].index[0]

# Remove all rows before the first game that starts with 'A'
df_filtered = df_sorted.iloc[idx:]
df_filtered.head(10)
# Out:
#       Rank                                Name Platform    Year   Genre  \
# 1243  1245  LEGO Star Wars III: The Clone Wars     X360  2011.0  Action
# 6596  6598  LEGO Star Wars III: The Clone Wars       PC  2011.0  Action
# 906    908  LEGO Star Wars III: The Clone Wars      Wii  2011.0  Action
# 1748  1750  LEGO Star Wars III: The Clone Wars       DS  2011.0  Action
# 1667  1669  LEGO Star Wars III: The Clone Wars      PS3  2011.0  Action
# 575    576   LEGO Star Wars: The Complete Saga     X360  2007.0  Action
# 150    151   LEGO Star Wars: The Complete Saga      Wii  2007.0  Action
# 212    213   LEGO Star Wars: The Complete Saga       DS  2007.0  Action
# 657    659   LEGO Star Wars: The Complete Saga      PS3  2007.0  Action
# 1796  1798      LEGO Star Wars: The Video Game      GBA  2005.0  Action
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1243          LucasArts      0.84      0.54       0.0         0.13
# ...

# %%
# Delete all rows before the first 'A' game
df_filtered.shape
# Out:
# (9419, 11)

# %%
vgsales_new.shape
# Out:
# (11844, 11)

# %%
16598-11844
# Out:
# 4754

# %%
vgsales_new.head(5)
# Out:
#         Rank               Name Platform    Year       Genre  \
# 13179  13181         Freelancer       PC  2003.0  Simulation
# 15668  15671  Freestyle Metal X       GC  2003.0      Racing
# 11089  11091  Freestyle Metal X      PS2  2003.0      Racing
# 15135  15138  Freestyle Metal X       XB  2003.0      Racing
# 5366    5368            Freeway     2600  1980.0      Action
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 13179  Microsoft Game Studios      0.02      0.02       0.0         0.01
# 15668            Midway Games      0.01      0.00       0.0         0.00
# 11089            Midway Games      0.04      0.03       0.0         0.01
# 15135            Midway Games      0.02      0.00       0.0         0.00
# 5366               Activision      0.32      0.02       0.0         0.00
#
#        Global_Sales
# 13179          0.05
# 15668          0.02
# 11089          0.09
# 15135          0.02
# 5366           0.34

# %%
vgsales_new = vgsales_new.sort_values(by=['Name'])

# %%
vgsales_new.head(5)
# Out:
#         Rank               Name Platform    Year       Genre  \
# 13179  13181         Freelancer       PC  2003.0  Simulation
# 15668  15671  Freestyle Metal X       GC  2003.0      Racing
# 11089  11091  Freestyle Metal X      PS2  2003.0      Racing
# 15135  15138  Freestyle Metal X       XB  2003.0      Racing
# 5366    5368            Freeway     2600  1980.0      Action
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 13179  Microsoft Game Studios      0.02      0.02       0.0         0.01
# 15668            Midway Games      0.01      0.00       0.0         0.00
# 11089            Midway Games      0.04      0.03       0.0         0.01
# 15135            Midway Games      0.02      0.00       0.0         0.00
# 5366               Activision      0.32      0.02       0.0         0.00
#
#        Global_Sales
# 13179          0.05
# 15668          0.02
# 11089          0.09
# 15135          0.02
# 5366           0.34
